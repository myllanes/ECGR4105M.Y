# %% [markdown]
# <a href="https://colab.research.google.com/github/myllanes/ECGR4105M.Y/blob/main/MichaelYllanes_801299358_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Michael Yllanes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('https://raw.githubusercontent.com/myllanes/ECGR4105M.Y./main/D3.csv', na_values='*')

# %% [markdown]
# # Problem 1 X1

# %%
m = data.X1.size
X_0 = np.ones((m, 1))
X_0 = pd.DataFrame(X_0)
data.insert(0, "intercept",X_0)
display(data)
# Out:
#     intercept        X1        X2        X3         Y
# 0         1.0  0.000000  3.440000  0.440000  4.387545
# 1         1.0  0.040404  0.134949  0.888485  2.679650
# 2         1.0  0.080808  0.829899  1.336970  2.968490
# 3         1.0  0.121212  1.524848  1.785455  3.254065
# 4         1.0  0.161616  2.219798  2.233939  3.536375
# ..        ...       ...       ...       ...       ...
# 95        1.0  3.838384  1.460202  3.046061 -4.440595
# 96        1.0  3.878788  2.155152  3.494545 -4.458663
# 97        1.0  3.919192  2.850101  3.943030 -4.479995
# 98        1.0  3.959596  3.545051  0.391515 -3.304593
# 99        1.0  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 5 columns]

# %%
CX1 = data.loc[:,['intercept','X1']]
CY1 = data.Y
theta1 = np.zeros(2)
iterations1 = 500;
alpha1 = 0.1;

# %%
def computeCost(X,y,theta):
  m = len(X)
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

# %%
def gradientDescent(X, y, theta, alpha, iterations):
  cost_history = np.zeros(iterations)

  for i in range(iterations):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sum_delta = (alpha / m) * X.transpose().dot(errors);
    theta = theta - sum_delta;
    cost_history[i] = computeCost(X, y, theta)
  return theta, cost_history

# %%
Xarray1 = CX1.loc[:,['intercept','X1']].values
Yarray1 = CY1.values
theta1, cost_history1 = gradientDescent(Xarray1, Yarray1, theta1, alpha1, iterations1)
print('X1 Final value of theta =', theta1)
#print('X1 cost_history =', cost_history1)
# Out:
# X1 Final value of theta = [ 5.92794892 -2.03833663]

# %%
# Column of index 1 only
plt.scatter(CX1.X1, CY1, color='red', marker= '^', label= 'Training Data')
plt.plot(CX1.X1, CX1.dot(theta1), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations1 + 1),cost_history1, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
# Grid to calculate J for X1
theta0_vals1 = np.linspace(4, 8, 500);
theta1_vals1 = np.linspace(-3, -1, 100);
# Set J vals to a matrix
J_vals_1 = np.zeros(shape = (len(theta1_vals1),len(theta0_vals1)));
for i in range(len(theta0_vals1)):
  for j in range(len(theta1_vals1)):
    t = [theta0_vals1[i], theta1_vals1[j]]
    J_vals_1[j,i] = computeCost(CX1, CY1, t)

# %%
#print (J_vals_1)

# %%
import matplotlib.pyplot as plt
# Plot J_vals
plt.contour(theta0_vals1, theta1_vals1, np.log(J_vals_1))
plt.xlabel('$theta_0$')
plt.ylabel('$theta_1$')
plt.scatter(theta1[0],theta1[1])
plt.grid()
plt.show()

# %% [markdown]
# # Problem 1 X2

# %%
CX2 = data.loc[:,['intercept','X2']]
CY2 = data.Y
theta2 = np.zeros(2)
iterations2 = 200;
alpha2 = 0.03;

# %%
Xarray2 = CX2.loc[:,['intercept','X2']].values
Yarray2 = CY2.values
theta2, cost_history2 = gradientDescent(Xarray2, Yarray2, theta2, alpha2, iterations2)
print('X1 Final value of theta =', theta2)
#print('X1 cost_history =', cost_history2)
# Out:
# X1 Final value of theta = [0.70477774 0.56978312]

# %%
plt.scatter(CX2.X2, CY2, color='red', marker= '^', label= 'Training Data')
plt.plot(CX2.X2, CX2.dot(theta2), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations2 + 1),cost_history2, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
# Grid to calculate J for X2
theta0_vals2 = np.linspace(-5, 5, 500);
theta1_vals2 = np.linspace(-5, 5, 100);
# Set J vals to a matrix
J_vals_2 = np.zeros(shape = (len(theta1_vals2),len(theta0_vals2)));
for i in range(len(theta0_vals2)):
  for j in range(len(theta1_vals2)):
    t2 = [theta0_vals2[i], theta1_vals2[j]]
    J_vals_2[j,i] = computeCost(CX2, CY2, t2)

# %%
#print (J_vals_1)

# %%
# Plot J_vals

plt.contour(theta0_vals2, theta1_vals2, np.log(J_vals_2))
plt.xlabel('$theta_0$')
plt.ylabel('$theta_1$')
plt.scatter(theta2[0],theta2[1])
plt.grid()
plt.show()

# %% [markdown]
# # Problem 1 X3

# %%
CX3 = data.loc[:,['intercept','X3']]
CY3 = data.Y
theta3 = np.zeros(2)
iterations3 = 800;
alpha3 = 0.02;

# %%
Xarray3 = CX3.loc[:,['intercept','X3']].values
Yarray3 = CY3.values
theta3, cost_history3 = gradientDescent(Xarray3, Yarray3, theta3, alpha3, iterations3)
print('X1 Final value of theta =', theta3)
#print('X1 cost_history =', cost_history3)
# Out:
# X1 Final value of theta = [ 2.86945679 -0.51970561]

# %%
plt.scatter(CX3.X3, CY3, color='red', marker= '^', label= 'Training Data')
plt.plot(CX3.X3, CX3.dot(theta3), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations3 + 1),cost_history3, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
# Grid to calculate J for X3
theta0_vals3 = np.linspace(-5, 13, 500);
theta1_vals3 = np.linspace(-5, 5, 100);
# Set J vals to a matrix
J_vals_3 = np.zeros(shape = (len(theta1_vals3),len(theta0_vals3)));
for i in range(len(theta0_vals3)):
  for j in range(len(theta1_vals3)):
    t3 = [theta0_vals3[i], theta1_vals3[j]]
    J_vals_3[j,i] = computeCost(CX3, CY3, t3)

# %%
plt.contour(theta0_vals3, theta1_vals3, np.log(J_vals_3))
plt.xlabel('$theta_0$')
plt.ylabel('$theta_1$')
plt.scatter(theta3[0],theta3[1])
plt.grid()
plt.show()

# %% [markdown]
# # Problem 2

# %%
# Define the compute_cost function
def compute_cost2(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1/(2*m)) * np.sum(np.square(predictions - y))
    return cost

# Define the gradient_descent function
def gradient_descent2(X, y, theta, alpha, iterations):
    m = len(y)
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        gradient = (1/m) * X.T.dot(errors)
        theta -= alpha * gradient
        cost_history[i] = compute_cost2(X, y, theta)

    return theta, cost_history

# %%
CX4 = data.loc[:,['intercept','X1','X2','X3']]
CY4 = data.Y

iterations4 = 3000;
alpha4 = 0.01;

# %%
Xarray4 = CX4.loc[:,['intercept','X1','X2','X3']].values
Yarray4 = CY4.values
theta4 = np.zeros(Xarray4.shape[1])
theta4, cost_history4 = gradient_descent2(Xarray4, Yarray4, theta4, alpha4, iterations4)
print('X1 Final value of theta =', theta4)
print('X1 cost_history =', cost_history4)
# Out:
# X1 Final value of theta = [ 5.05362928 -1.96691398  0.57561561 -0.22741231]
# X1 cost_history = [5.21542243 4.97171977 4.7765543  ... 0.74209453 0.7420873  0.74208008]

# %%
plt.scatter(Xarray4[:, 1], Yarray4, color='blue', label='X1')  # X1
plt.scatter(Xarray4[:, 2], Yarray4, color='red', label='X2')   # X2
plt.scatter(Xarray4[:, 3], Yarray4, color='black', label='X3') # X3

plt.plot(Xarray4[:, 1], CX4.dot(theta4), color='green', label='Regression Line')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations4 + 1),cost_history4, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %% [markdown]
# # Michael Yllanes

# %%
#Michael
